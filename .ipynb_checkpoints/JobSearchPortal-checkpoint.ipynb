# %%
from bs4 import BeautifulSoup
import requests
JobTitle=[]
CompanyName=[]
KeySkills=[]
Experience=[]
JobLocation=[]
JobSalary=[]
JobDescription=[]

#html_text= requests.get('https://www.timesjobs.com/candidate/job-search.html?from=submit&actualTxtKeywords=work%20from%20home&searchBy=0&rdoOperator=OR&searchType=personalizedSearch&luceneResultSize=25&postWeek=60&txtKeywords=work%20from%20home&pDate=I&sequence=1&startPage=0').text
url2="https://www.timesjobs.com/candidate/job-search.html?from=submit&actualTxtKeywords=Non%20IT&searchBy=0&rdoOperator=OR&searchType=personalizedSearch&luceneResultSize=25&postWeek=60&txtKeywords=non%20it&pDate=I&sequence=2&startPage="
url= "https://www.timesjobs.com/candidate/job-search.html?from=submit&actualTxtKeywords=work%20from%20home&searchBy=0&rdoOperator=OR&searchType=personalizedSearch&luceneResultSize=25&postWeek=60&txtKeywords=work%20from%20home&pDate=I&sequence=1&startPage="

df = pd.read_csv('SaleryLink1Step6.csv')

def Scrape_Url(url,max_pages):
    
    current_page = 2501
    
    while current_page<= max_pages:
        current_url= url+str(current_page)
        #print(current_url)
        html_text=requests.get(current_url).text
        Scrapping(html_text) 
        current_page= current_page+1
    
def Scrapping(html_text): 
    soup= BeautifulSoup(html_text, 'lxml')
    jobs= soup.find_all('li', class_="clearfix job-bx wht-shd-bx")
    for job in jobs:
        #---------------Company Name---------------------------------------------------
        company= job.find('h3', class_= 'joblist-comp-name').text.replace(' ', '').strip()
        b= company.count("(MoreJobs)")
        if b>=1:
            cmp_name= company.replace('(MoreJobs)', '').strip()
            CompanyName.append(cmp_name)
        else:
            CompanyName.append(company)


        #----------------Skills-------------------------------------------------------------
        skills= job.find('span', class_= 'srp-skills').text.replace(' ', '').strip()
        KeySkills.append(skills)

        #----------------Job Title-------------------------------------------------------------
        title= job.find('a').text.replace(' ', ' ').strip()
        JobTitle.append(title)


         #---------------Experience-------------------------------------------------------------
        ex= job.find('ul', class_= 'top-jd-dtl clearfix') 
        exp= ex.find('li' ).text.replace('card_travel', '').strip()
        Experience.append(exp)


        #---------------Job Location-------------------------------------------------------------
        lo= job.find('ul', class_= 'top-jd-dtl clearfix') 
        #print(lo)
        loc= ex.find('span' ).text.strip()
        JobLocation.append(loc)

        #---------------Salary-------------------------------------------------------------
        sa= job.find('ul', class_= 'top-jd-dtl clearfix') 

        sal= ex.find_all('i', class_= 'material-icons rupee')

        if not sal:
            ok='None'
            JobSalary.append(ok)
        else:
            repo =job.find('ul',class_="top-jd-dtl clearfix").find_all('li')[1]
            JobSalary.append(repo.text.strip())

        #---------------Job Description-------------------------------------------------------------
        d= job.find('ul', class_= 'list-job-dtl clearfix') 
        des=d.find('li').text.replace('Job Description:', '').strip()
        JobDescription.append(des)
    
    
    
    
#Scrapping(html_text) 
#Max Pages would be approx 9 thousandd
Scrape_Url(url,3500) 

#Max Pages would be approx 6596 thousand
# Scrape_Url(url2,0) 

print(len(KeySkills))
print(len(CompanyName))
print(len(JobTitle))
print(len(Experience))
print(len(JobLocation))
print(len(JobSalary))
print(len(JobDescription))


print(CompanyName)
#print(KeySkills)
#print(JobTitle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-42394d2a8a83> in <module>
#      13 url= "https://www.timesjobs.com/candidate/job-search.html?from=submit&actualTxtKeywords=work%20from%20home&searchBy=0&rdoOperator=OR&searchType=personalizedSearch&luceneResultSize=25&postWeek=60&txtKeywords=work%20from%20home&pDate=I&sequence=1&startPage="
#      14
# ---> 15 df = pd.read_csv('SaleryLink1Step6.csv')
#      16
#      17 def Scrape_Url(url,max_pages):
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
# df = pd.read_csv('Salery.csv')
df1 = pd.DataFrame(data) 
# print(df1)
# dfMerge =  df1.append(df,ignore_index = True )
# print(df1)
df1.to_csv('SaleryLink1Step6.csv', mode='a',index=False, header=False, encoding='utf-8')

# %%
JobTitle=["sdjhfjksdfksdjhfsdjkhf"]
CompanyName=["asuidhzxjchasiud"]
KeySkills=["ejsaandev"]
Experience=["mehsaandev"]
JobLocation=["Muhammad ERHsaann"]
JobSalary=["asdjasjdas"]
JobDescription=["sdhjskahdioqwuqweouqweuq"]
data = {'Job Title':JobTitle,'Company Name':CompanyName,'Job Location':JobLocation, 'Job Salery':JobSalary , 'Job Description':JobDescription,'Key Skills':KeySkills,'Experience':Experience}
print(data)
# Out:
# {'Job Title': ['sdjhfjksdfksdjhfsdjkhf'], 'Company Name': ['asuidhzxjchasiud'], 'Job Location': ['Muhammad ERHsaann'], 'Job Salery': ['asdjasjdas'], 'Job Description': ['sdhjskahdioqwuqweouqweuq'], 'Key Skills': ['ejsaandev'], 'Experience': ['mehsaandev']}

# %%
#1st List
Array = pd.read_csv("SaleryLink1Step5.csv")
for i in range(len(Array)):
    JobTitle.append(Array["Job Title"][i])
    CompanyName.append(Array["Company Name"][i])
    KeySkills.append(Array["Key Skills"][i])
    Experience.append(Array["Experience"][i])
    JobLocation.append(Array["Job Location"][i]) 
    JobSalary.append(Array["Job Salery"][i])
    JobDescription.append(Array["Job Description"][i])

# %%
print(len(JobTitle))

# %%
import pandas as pd
  
# Creating the first Dataframe using dictionary
df1 = pd.DataFrame({"a":[1, 2, 3, 4],
                    "b":[5, 6, 7, 8]})
  
# Creating the Second Dataframe using dictionary
df2 = pd.DataFrame({"a":[1, 2, 3],
                    "b":[5, 6, 7], 
                    "c":[1, 5, 4]})
  
# for appending df2 at the end of df1
df1.append(df2, ignore_index = True)
# Out:
#    a  b    c
# 0  1  5  NaN
# 1  2  6  NaN
# 2  3  7  NaN
# 3  4  8  NaN
# 4  1  5  1.0
# 5  2  6  5.0
# 6  3  7  4.0
